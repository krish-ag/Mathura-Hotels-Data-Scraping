# %%
import pandas as pd
import json

# %%
with open('data.json') as f:
    data = json.load(f)

# %%
hotels = data['response']['personalizedSections'][0]['hotels'] + data['response']['personalizedSections'][1]['hotels']

# %%
hotels[0]
# Out:
# {'id': '20130504140408935',
#  'name': 'Nidhivan Sarovar Portico-Vrindavan Mathura',
#  'maskedPropertyName': False,
#  'propertyType': 'Hotel',
#  'propertyLabel': 'Hotel',
#  'stayType': 'Hotel',
#  'starRating': 4,
#  'soldOut': False,
#  'showCallToBook': False,
#  'showSimilarChainProperty': False,
#  'groupBookingHotel': False,
#  'groupBookingPrice': False,
#  'maskedPrice': False,
#  'isGroupBookingForSimilar': False,
#  'trackingMap': {},
#  'alternateDates': False,
#  'multiRoomRecommendation': False,
#  'isAltAcco': False,
#  'mtKey': '1334815084738622622',
#  'totalImageCount': 20,
#  'travellerImageCount': 0,
#  'categories': ['Chain',
#   'Deals for Vaccinated Travellers',
#   'Couple',
#   'Workation',
#   'Quarantine hotels',
#   'Extended Stays',
#   'Room with a View',
#   'MyBiz Assured',
#   'Beachfront',
#   'myp_cat_c',
#   'MyBiz_Assured',
#   'Premium Properties',
#   'premium_hotels'],
#  'locationPersuasion': ['In Vrindavan',
#   '14.1 km from Mathura',
# ...

# %%
json.dump(hotels, open('hotels.json', 'w'))
